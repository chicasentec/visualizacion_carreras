# %% [markdown]
# # ETL

# %%
import pandas as pd
import os
from scripts.georef import add_unidades_territoriales_to_df

# %% [markdown]
# ## Carga de inputs

# %%
df_alumnos = pd.read_csv('data/input/alumnos.csv',delimiter=',')
df_carreras = pd.read_csv('data/input/carreras.csv',delimiter=',')

if os.path.exists('data/output/universidades.csv'):
    df_universidades = pd.read_csv('data/output/universidades.csv',delimiter=',',dtype={"provincia_id":str})
else:
    df_universidades_raw = pd.read_csv('data/input/universidades.csv',delimiter=',')
    df_universidades_raw["lat"] = df_universidades_raw['coordenadas'].str.split(",").str[0]
    df_universidades_raw["lon"] = df_universidades_raw['coordenadas'].str.split(",").str[1]
    df_universidades = add_unidades_territoriales_to_df(df_universidades_raw, lat_col="lat", lon_col="lon")
    df_universidades.to_csv('data/output/universidades.csv', sep=',', encoding='utf8', index=False)
# Out:
# Consultando lat: -36.4494181, lon: -57.7686044
# Consultando lat: -34.6021735, lon: -58.3972997
# Consultando lat: -34.6028340446427, lon: -58.368183272295
# Consultando lat: -31.4337174, lon: -64.2779779
# Consultando lat: -34.5547176, lon: -58.4972877
# Consultando lat: -31.4421202, lon: -64.2033758
# Consultando lat: -34.5951617, lon: -58.4021427
# Consultando lat: -34.6142528, lon: -58.371724
# Consultando lat: -34.6196133, lon: -58.4382653
# Consultando lat: -34.567895, lon: -58.4361568
# Consultando lat: -34.6030978, lon: -58.3739408
# Consultando lat: -34.57439170160686, lon: -58.43650022052455
# Consultando lat: -32.9512965, lon: -60.6460659
# Consultando lat: -34.5997447, lon: -58.3934405
# Consultando lat: -34.6071979, lon: -58.4291149
# Consultando lat: -34.5809241, lon: -58.4253568
# Consultando lat: -34.6307959, lon: -58.4656187
# Consultando lat: -32.9415838, lon: -60.6705633
# Consultando lat: -34.6097284, lon: -58.4079993
# Consultando lat: -34.5946906, lon: -58.4018519
# Consultando lat: -34.5945248, lon: -58.469703
# Consultando lat: -39.0178878, lon: -67.5960898
# Consultando lat: -34.5453018, lon: -58.4519636
# Consultando lat: -34.6148453, lon: -58.3668853
# Consultando lat: -34.6148113, lon: -58.3940258
# Consultando lat: -34.6221199173329, lon:  -58.379325181549746
# Consultando lat: -32.0759594, lon: -60.4665987
# Consultando lat: -34.6173746323554, lon: -58.381525671564
# Consultando lat: -34.60762266844467, lon: -58.38645625343852
# Consultando lat: -37.1552476, lon: -57.7427199
# Consultando lat: -34.47094214462022, lon:  -58.847032888622834
# Consultando lat: -32.0752125, lon: -61.5334031
# Consultando lat: -34.59603749231513, lon: -58.39193924933041
# Consultando lat: -34.608865810462795, lon: -58.378716306442456
# Consultando lat: -31.4527657, lon: -64.2513093
# Consultando lat: -31.5403667, lon: -68.5882198
# Consultando lat: -34.924457391060656, lon:  -57.950327388915824
# Consultando lat: -27.3558553, lon: -55.9417525
# Consultando lat: -24.7399552, lon: -65.3940334
# Consultando lat: -31.607095036472234, lon:  -60.67088878632154
# Consultando lat: -34.46911816523541, lon: -58.51514668806574
# Consultando lat: -33.8848483, lon: -67.5266833
# Consultando lat: -31.749467, lon:  -60.504221
# Consultando lat: -33.332260, lon:  -60.206182
# Consultando lat: -32.954580, lon:  -60.644244
# Consultando lat: -29.409282, lon:  -66.831225
# Consultando lat: -27.451164, lon:  -58.979211
# Consultando lat: -34.178845, lon:  -58.962087
# Consultando lat: -33.110736, lon:  -64.299507
# Consultando lat: -31.624005177104273, lon: -58.50507853279984
# Consultando lat: -40.824221, lon:  -62.978906
# Consultando lat: -31.435579, lon:  -64.174509
# Consultando lat: -23.519824, lon:  -46.672244
# Consultando lat: -34.257332, lon:  -59.479764

# %%
# quitamos los datos del año 2010 ya que la UBA no entrega datos para este año
# si se desean incluir en en análisis tener en cuenta que va a haber una bajada en las cantidades totales para ese año, debido a eso
df_alumnos = df_alumnos[df_alumnos.anio != 2010]

# %% [markdown]
# ## Exporacion

# %%
df_carreras.head(10)
# Out:
#                                              carrera carrera_grupo  \
# 0                                            Abogado     Juridicas
# 1      Abogado - Ciclo de Complementacion Curricular     Juridicas
# 2                                       Abogado - MD     Juridicas
# 3                                Abogado (Plan 2017)     Juridicas
# 4  Abogado Especialista en Administracion de Just...     Juridicas
# 5  Abogado especialista en Asesoramiento de Empresas     Juridicas
# 6  Abogado Especialista en Asesoria Juridica de E...     Juridicas
# 7  Abogado Especialista en Contratos y Derechos d...     Juridicas
# 8  Abogado especialista en Derecho Administrativo...     Juridicas
# 9  Abogado Especialista en Derecho Administrativo...     Juridicas
#
#   Carrera_normalizada
# 0            Abogacia
# 1            Abogacia
# 2            Abogacia
# 3            Abogacia
# 4            Abogacia
# 5            Abogacia
# 6            Abogacia
# 7            Abogacia
# 8            Abogacia
# 9            Abogacia

# %%
df_alumnos.head(10)
# Out:
#       anio institucion_tipo                 institucion_nombre  \
# 7315  2011      Universidad  Universita Degli Studi di Bologna
# 7316  2011      Universidad      Universidad Torcuato Di Tella
# 7317  2011      Universidad      Universidad Torcuato Di Tella
# 7318  2011      Universidad      Universidad Torcuato Di Tella
# 7319  2011      Universidad      Universidad Torcuato Di Tella
# 7320  2011      Universidad      Universidad Torcuato Di Tella
# 7321  2011      Universidad      Universidad Torcuato Di Tella
# 7322  2011      Universidad      Universidad Torcuato Di Tella
# 7323  2011      Universidad      Universidad Torcuato Di Tella
# 7324  2011      Universidad      Universidad Torcuato Di Tella
#
#                  institucion_nombre_new institucion_nombre_unidad_academica  \
# 7315  Universita Degli Studi di Bologna   Universita Degli Studi di Bologna
# 7316      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7317      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7318      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7319      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7320      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7321      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7322      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7323      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7324      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
#
#                                        unidad_academica  \
# 7315                  Università Degli Studi di Bologna
# 7316  Departamento de Ciencia Politica y Estudios In...
# 7317  Departamento de Ciencia Politica y Estudios In...
# 7318  Departamento de Ciencia Politica y Estudios In...
# 7319  Departamento de Ciencia Politica y Estudios In...
# 7320  Departamento de Ciencia Politica y Estudios In...
# 7321                           Departamento de Economia
# 7322                           Departamento de Economia
# 7323                           Departamento de Economia
# 7324                           Departamento de Historia
#
#                                    unidad_academica_new  \
# 7315                  Università Degli Studi di Bologna
# 7316  Departamento de Ciencia Politica y Estudios In...
# 7317  Departamento de Ciencia Politica y Estudios In...
# 7318  Departamento de Ciencia Politica y Estudios In...
# 7319  Departamento de Ciencia Politica y Estudios In...
# 7320  Departamento de Ciencia Politica y Estudios In...
# 7321                           Departamento de Economia
# 7322                           Departamento de Economia
# 7323                           Departamento de Economia
# 7324                           Departamento de Historia
#
#                                          carrera_titulo institucion_gestion  \
# 7315  Magister en Relaciones Internacionales Europa ...             Privada
# 7316                         Doctor en Ciencia Politica             Privada
# 7317        Licenciatura en Ciencia Politica y Gobierno             Privada
# 7318                       Magister en Ciencia Politica             Privada
# 7319           Licenciatura en Estudios Internacionales             Privada
# 7320               Magister en Estudios Internacionales             Privada
# 7321                           Licenciatura en Economia             Privada
# 7322                            Magister en Econometria             Privada
# 7323                               Magister en Economia             Privada
# 7324                                 Doctor en Historia             Privada
#
#      carrera_titulo_nivel  ... estudiantes_mujeres  nuevos_inscriptos_total  \
# 7315             Posgrado  ...                54.0                     30.0
# 7316             Posgrado  ...                10.0                      2.0
# 7317                Grado  ...                39.0                     23.0
# 7318             Posgrado  ...                18.0                     15.0
# 7319                Grado  ...                71.0                     35.0
# 7320             Posgrado  ...               100.0                     34.0
# 7321                Grado  ...                49.0                     42.0
# 7322             Posgrado  ...                18.0                     12.0
# 7323             Posgrado  ...                14.0                     25.0
# 7324             Posgrado  ...                13.0                      NaN
#
#       nuevos_inscriptos_varones  nuevos_inscriptos_mujeres  \
# 7315                       13.0                       17.0
# 7316                        NaN                        2.0
# 7317                       10.0                       13.0
# 7318                       12.0                        3.0
# 7319                       13.0                       22.0
# 7320                       15.0                       19.0
# 7321                       28.0                       14.0
# 7322                        9.0                        3.0
# 7323                       20.0                        5.0
# 7324                        NaN                        NaN
#
#       reinscriptos_total  reinscriptos_varones  reinscriptos_mujeres  \
# 7315                 NaN                   NaN                   NaN
# 7316                 NaN                   NaN                   NaN
# 7317                49.0                  23.0                  26.0
# 7318                 NaN                   NaN                   NaN
# 7319                75.0                  26.0                  49.0
# 7320                 NaN                   NaN                   NaN
# 7321               117.0                  82.0                  35.0
# 7322                 NaN                   NaN                   NaN
# 7323                 NaN                   NaN                   NaN
# 7324                 NaN                   NaN                   NaN
#
#       egresados_total  egresados_varones  egresados_mujeres
# 7315             29.0               14.0               15.0
# 7316              NaN                NaN                NaN
# 7317              6.0                4.0                2.0
# 7318              NaN                NaN                NaN
# 7319             28.0                7.0               21.0
# 7320              9.0                5.0                4.0
# 7321             36.0               24.0               12.0
# 7322              1.0                NaN                1.0
# 7323              2.0                2.0                NaN
# 7324              1.0                NaN                1.0
#
# [10 rows x 23 columns]

# %%
df_universidades.head(10)
# Out:
#                                   universidad_nombre  \
# 0                  Escuela Universitaria de Teologia
# 1      Facultad Latinoamericana de Ciencias Sociales
# 2              Instituto Tecnologico de Buenos Aires
# 3                Instituto Universitario Aeronautico
# 4                      Instituto Universitario CEMIC
# 5  Instituto Universitario de Ciencias Biomedicas...
# 6  Instituto Universitario de Ciencias de la Salu...
# 7    Instituto Universitario de Gendarmeria Nacional
# 8  Instituto Universitario de la Policia Federal ...
# 9  Instituto Universitario de Salud Mental de la ...
#
#                                   institucion_nombre  \
# 0                  Escuela Universitaria de Teologia
# 1      Facultad Latinoamericana de Ciencias Sociales
# 2              Instituto Tecnologico de Buenos Aires
# 3                Instituto Universitario Aeronautico
# 4                      Instituto Universitario CEMIC
# 5  Instituto Universitario de Ciencias Biomedicas...
# 6  Instituto Universitario de Ciencias de la Salu...
# 7    Instituto Universitario de Gendarmeria Nacional
# 8  Instituto Universitario de la Policia Federal ...
# 9  Instituto Universitario de Salud Mental de la ...
#
#              institucion_direccion  \
# 0             Pasaje Catedral 1750
# 1                     Tucuman 1966
# 2           Av. Eduardo Madero 399
# 3  Av. Fuerza Aerea Argentina 6500
# 4                  Valdenegro 4337
# 5          Naciones Unidas 400-440
# 6         Av. Gral. Las Heras 1907
# 7              Av. Paseo Colon 533
# 8                      Rosario 532
# 9                         Baez 248
#
#                                                  api  \
# 0                                                NaN
# 1                                                NaN
# 2  http://apis.datos.gob.ar/georef/api/direccione...
# 3  http://apis.datos.gob.ar/georef/api/direccione...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                           coordenadas  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0             -36.4494181,-57.7686044         NaN         NaN         NaN
# 1             -34.6021735,-58.3972997         NaN         NaN         NaN
# 2  -34.6028340446427,-58.368183272295         NaN         NaN         NaN
# 3             -31.4337174,-64.2779779         NaN         NaN         NaN
# 4             -34.5547176,-58.4972877         NaN         NaN         NaN
# 5             -31.4421202,-64.2033758         NaN         NaN         NaN
# 6             -34.5951617,-58.4021427         NaN         NaN         NaN
# 7              -34.6142528,-58.371724         NaN         NaN         NaN
# 8             -34.6196133,-58.4382653         NaN         NaN         NaN
# 9              -34.567895,-58.4361568         NaN         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  ...  latitud_x  longitud_x  departamento_id_y  \
# 0         NaN         NaN  ... -36.449418  -57.768604              06238
# 1         NaN         NaN  ... -34.602173  -58.397300              02021
# 2         NaN         NaN  ... -34.602834  -58.368183              02007
# 3         NaN         NaN  ... -31.433717  -64.277978              14014
# 4         NaN         NaN  ... -34.554718  -58.497288              02084
# 5         NaN         NaN  ... -31.442120  -64.203376              14014
# 6         NaN         NaN  ... -34.595162  -58.402143              02014
# 7         NaN         NaN  ... -34.614253  -58.371724              02007
# 8         NaN         NaN  ... -34.619613  -58.438265              02042
# 9         NaN         NaN  ... -34.567895  -58.436157              02098
#
#    departamento_nombre_y  municipio_id_y  municipio_nombre_y  provincia_id_y  \
# 0                Dolores          060238             Dolores              06
# 1               Comuna 3            None                None              02
# 2               Comuna 1            None                None              02
# 3                Capital          140077             Córdoba              14
# 4              Comuna 12            None                None              02
# 5                Capital          140077             Córdoba              14
# 6               Comuna 2            None                None              02
# 7               Comuna 1            None                None              02
# 8               Comuna 6            None                None              02
# 9              Comuna 14            None                None              02
#
#                 provincia_nombre_y          latitud_y        longitud_y
# 0                     Buenos Aires        -36.4494181       -57.7686044
# 1  Ciudad Autónoma de Buenos Aires        -34.6021735       -58.3972997
# 2  Ciudad Autónoma de Buenos Aires  -34.6028340446427  -58.368183272295
# 3                          Córdoba        -31.4337174       -64.2779779
# 4  Ciudad Autónoma de Buenos Aires        -34.5547176       -58.4972877
# 5                          Córdoba        -31.4421202       -64.2033758
# 6  Ciudad Autónoma de Buenos Aires        -34.5951617       -58.4021427
# 7  Ciudad Autónoma de Buenos Aires        -34.6142528        -58.371724
# 8  Ciudad Autónoma de Buenos Aires        -34.6196133       -58.4382653
# 9  Ciudad Autónoma de Buenos Aires         -34.567895       -58.4361568
#
# [10 rows x 44 columns]

# %% [markdown]
# ## Calculo evolucion de genero en carreras

# %%
#El archivo alumnos es el que entrega el ministerio
#En el archivo carreras realizamos nuestro mapeo asignandole a cada titulo un grupo (Juridicas, Exactas, Naturales, etc) y un nombre normalizado 
df_alumnos_merged = df_alumnos.merge(df_carreras, how="left", left_on="carrera_titulo", right_on="carrera")

# %%
#Incluimos esta validacion aqui para asegurarnos de que no queden carreras sin mappear
col_nulls = df_alumnos_merged.isnull().any()
col_nulls
# Out:
# anio                                   False
# institucion_tipo                       False
# institucion_nombre                     False
# institucion_nombre_new                 False
# institucion_nombre_unidad_academica    False
# unidad_academica                       False
# unidad_academica_new                   False
# carrera_titulo                         False
# institucion_gestion                    False
# carrera_titulo_nivel                   False
# Modalidad                              False
# estudiantes_total                       True
# estudiantes_varones                     True
# estudiantes_mujeres                     True
# nuevos_inscriptos_total                 True
# nuevos_inscriptos_varones               True
# nuevos_inscriptos_mujeres               True
# reinscriptos_total                      True
# reinscriptos_varones                    True
# reinscriptos_mujeres                    True
# egresados_total                         True
# egresados_varones                       True
# egresados_mujeres                       True
# carrera                                False
# carrera_grupo                          False
# Carrera_normalizada                     True
# dtype: bool

# %% [markdown]
# ## Validacion y solucion de inconsistencias

# %%
df_alumnos_merged.carrera_grupo.isnull().value_counts()
# No debería haber Nulls en True ya que eso quiere decir que no se pudo matchear el nombre del titulo entre alumnos.csv y carreras.csv
# Este caso solo debería darse si, por ejemplo, se agrega un nuevo año con carreras "nuevas" o con nombres un poco diferentes a los que teníamos hasta el momento
# Out:
# False    65662
# Name: carrera_grupo, dtype: int64

# %%
#Si hubiera inconsistencias las guardamos en este archivo para analizar más comodamente
nulos = df_alumnos_merged[df_alumnos_merged.carrera_grupo.isnull()]
nulos.to_csv("data/validacion/nulls-revisar.csv", encoding = "UTF8", index = False)
titulos_nuevos = pd.DataFrame(data=nulos.carrera_titulo.unique())
titulos_nuevos.to_csv("data/validacion/titulos_nuevos.csv", encoding = "UTF8", index = False)

# %%
variables = [
    "estudiantes_total","estudiantes_varones","estudiantes_mujeres",
    "nuevos_inscriptos_total","nuevos_inscriptos_varones","nuevos_inscriptos_mujeres",
    "egresados_total","egresados_varones","egresados_mujeres",
]

# %%
df_evolucion_carrera = df_alumnos_merged.groupby(["anio","carrera_grupo"]).sum()

# %%
df_evolucion_carrera = df_evolucion_carrera[variables]
df_evolucion_carrera = df_evolucion_carrera.reset_index()

# %%
df_evolucion_carrera.head(10)
# Out:
#    anio                     carrera_grupo  estudiantes_total  \
# 0  2011          Arquitectura y Urbanismo            60303.0
# 1  2011                             Artes            53170.0
# 2  2011                      Comunicacion           113474.0
# 3  2011                            Diseño            52552.0
# 4  2011                        Economicas           318405.0
# 5  2011                         Educacion           139802.0
# 6  2011                           Exactas            23899.0
# 7  2011  Hoteleria, Gastronomia y Turismo            25790.0
# 8  2011                       Informatica           163968.0
# 9  2011                        Ingenieria           124298.0
#
#    estudiantes_varones  estudiantes_mujeres  nuevos_inscriptos_total  \
# 0              31217.0              29086.0                   9743.0
# 1              22164.0              31006.0                  13305.0
# 2              40764.0              72710.0                  25473.0
# 3              18574.0              33978.0                  11127.0
# 4             149696.0             168709.0                  67062.0
# 5              32933.0             106869.0                  42465.0
# 6              11515.0              12384.0                   5491.0
# 7               8221.0              17569.0                   6917.0
# 8             132685.0              31283.0                  37090.0
# 9             101296.0              23002.0                  25854.0
#
#    nuevos_inscriptos_varones  nuevos_inscriptos_mujeres  egresados_total  \
# 0                     4859.0                     4884.0           3064.0
# 1                     6016.0                     7289.0           1418.0
# 2                     9914.0                    15559.0           7104.0
# 3                     3813.0                     7314.0           2826.0
# 4                    33017.0                    34045.0          19059.0
# 5                    10907.0                    31558.0           8611.0
# 6                     2516.0                     2975.0           1479.0
# 7                     2395.0                     4522.0           1513.0
# 8                    30891.0                     6199.0           7554.0
# 9                    20815.0                     5039.0           5885.0
#
#    egresados_varones  egresados_mujeres
# 0             1412.0             1652.0
# 1              503.0              915.0
# 2             2141.0             4963.0
# 3              820.0             2006.0
# 4             8970.0            10089.0
# 5             1814.0             6797.0
# 6              633.0              846.0
# 7              364.0             1149.0
# 8             5702.0             1852.0
# 9             4682.0             1203.0

# %%
df_evolucion_carrera["estudiantes_mujeres_pct"] = df_evolucion_carrera.estudiantes_mujeres/df_evolucion_carrera.estudiantes_total
#incriptas como predictor de composicion e interes.
df_evolucion_carrera["inscripciones_mujeres_pct"] = df_evolucion_carrera.nuevos_inscriptos_mujeres/df_evolucion_carrera.nuevos_inscriptos_total
#agregar ratio de hombres
df_evolucion_carrera["estudiantes_hombres_pct"] = df_evolucion_carrera.estudiantes_varones/df_evolucion_carrera.estudiantes_total

# %%
df_evolucion_carrera.to_csv("data/output/grupos_evolucion_genero.csv", encoding = "UTF8", index = False)

# %% [markdown]
# ## Grafico exploratorio

# %% [markdown]
# ### carreras

# %%
df_evolucion_carrera_carreras = df_alumnos_merged.groupby(["anio","carrera_grupo","Carrera_normalizada"]).sum()

# %%
df_evolucion_carrera_carreras = df_evolucion_carrera_carreras[variables]
df_evolucion_carrera_carreras = df_evolucion_carrera_carreras.reset_index()

# %%
df_evolucion_carrera_carreras["estudiantes_mujeres_pct"] = df_evolucion_carrera_carreras.estudiantes_mujeres/df_evolucion_carrera_carreras.estudiantes_total
#incriptas como predictor de composicion e interes.
df_evolucion_carrera_carreras["inscripciones_mujeres_pct"] = df_evolucion_carrera_carreras.nuevos_inscriptos_mujeres/df_evolucion_carrera_carreras.nuevos_inscriptos_total
#agregar ratio de hombres
df_evolucion_carrera_carreras["estudiantes_hombres_pct"] = df_evolucion_carrera_carreras.estudiantes_varones/df_evolucion_carrera_carreras.estudiantes_total

# %%
df_evolucion_carrera_carreras.to_csv("data/output/grupos_carreras_evolucion_genero.csv", encoding = "UTF8", index = False)

# %% [markdown]
# # Universidades

# %%
import csv


# acá analizo la nueva clave "institucion_nombre_unidad_academica" para los casos en los que (como la UTN) hay diferentes sedes
instituciones_en_alumnos = set(df_alumnos_merged.institucion_nombre_unidad_academica.unique())
instituciones_en_universidades = set(df_universidades.institucion_nombre.unique())

# chequea si hay instituciones faltantes para el merge (no debería haber)
faltantes = (instituciones_en_alumnos-instituciones_en_universidades)

with open('data/validacion/universidades_faltantes.csv', mode='w', encoding = "UTF8") as faltantes_file:
    faltantes_writer = csv.writer(faltantes_file, delimiter=',')
    for universidad in faltantes:
        print(universidad)
        faltantes_writer.writerow([universidad])

# %%
df_alumnos_por_universidad_geo = df_alumnos_merged.merge(df_universidades, how="left", left_on="institucion_nombre_unidad_academica", right_on="institucion_nombre")

df_alumnos_por_universidad_geo.head(10)
# Out:
#    anio institucion_tipo               institucion_nombre_x  \
# 0  2011      Universidad  Universita Degli Studi di Bologna
# 1  2011      Universidad      Universidad Torcuato Di Tella
# 2  2011      Universidad      Universidad Torcuato Di Tella
# 3  2011      Universidad      Universidad Torcuato Di Tella
# 4  2011      Universidad      Universidad Torcuato Di Tella
# 5  2011      Universidad      Universidad Torcuato Di Tella
# 6  2011      Universidad      Universidad Torcuato Di Tella
# 7  2011      Universidad      Universidad Torcuato Di Tella
# 8  2011      Universidad      Universidad Torcuato Di Tella
# 9  2011      Universidad      Universidad Torcuato Di Tella
#
#               institucion_nombre_new institucion_nombre_unidad_academica  \
# 0  Universita Degli Studi di Bologna   Universita Degli Studi di Bologna
# 1      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 2      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 3      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 4      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 5      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 6      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7      Universidad Torcuato Di Tella       Universidad Torcuato Di Tella
# 7  Ciudad Autónoma de Buenos Aires  -34.5476972  -58.4489394
# 8  Ciudad Autónoma de Buenos Aires  -34.5476972  -58.4489394
# 9  Ciudad Autónoma de Buenos Aires  -34.5476972  -58.4489394
#
# [10 rows x 70 columns]

# %%
df_alumnos_por_universidad_geo = df_alumnos_por_universidad_geo.reset_index()

variables_alumnos_por_univ = ['anio','institucion_nombre_unidad_academica', 'lat', 'lon', 'provincia_id_y', "carrera_grupo", "carrera_titulo"] + variables
df_alumnos_por_universidad_geo = df_alumnos_por_universidad_geo[variables_alumnos_por_univ]
df_alumnos_por_universidad_geo.rename(columns={'provincia_id_y':'provincia_id'}, inplace=True)
df_alumnos_por_universidad_geo = df_alumnos_por_universidad_geo.reset_index()

df_alumnos_por_universidad_geo["estudiantes_mujeres_pct"] = df_alumnos_por_universidad_geo.estudiantes_mujeres/df_alumnos_por_universidad_geo.estudiantes_total
#incriptas como predictor de composicion e interes.
df_alumnos_por_universidad_geo["inscripciones_mujeres_pct"] = df_alumnos_por_universidad_geo.nuevos_inscriptos_mujeres/df_alumnos_por_universidad_geo.nuevos_inscriptos_total
#agregar ratio de hombres
df_alumnos_por_universidad_geo["estudiantes_hombres_pct"] = df_alumnos_por_universidad_geo.estudiantes_varones/df_alumnos_por_universidad_geo.estudiantes_total

df_alumnos_por_universidad_geo = df_alumnos_por_universidad_geo.reset_index()

df_alumnos_por_universidad_geo.to_csv("data/output/alumnos_por_universidad_geo.csv", encoding = "UTF8", index = False)

# %%
df_evolucion_universidades = df_alumnos_por_universidad_geo.groupby(["anio","provincia_id", "carrera_grupo"]).sum()
#df_evolucion_universidades = df_evolucion_universidades[df_universidades_merged]
df_evolucion_universidades = df_evolucion_universidades.reset_index()

# %%
df_evolucion_universidades["estudiantes_mujeres_pct"] = df_evolucion_universidades.estudiantes_mujeres/df_evolucion_universidades.estudiantes_total

# %%
estudiantes_totales = df_evolucion_universidades.groupby(["anio", 'provincia_id']).sum()["estudiantes_total"]

# %%
df_evolucion_universidades['estudiantes_grupo_pct'] = df_evolucion_universidades.apply(
    lambda row: row["estudiantes_total"] / estudiantes_totales[row["anio"], row["provincia_id"]],
    axis=1
)

# %%
df_evolucion_universidades.head()
# Out:
#    anio provincia_id             carrera_grupo  level_0    index  \
# 0  2011           02  Arquitectura y Urbanismo   166256   166256
# 1  2011           02                     Artes   714222   714222
# 2  2011           02              Comunicacion  1227479  1227479
# 3  2011           02                    Diseño   332543   332543
# 4  2011           02                Economicas  1686778  1686778
#
#    estudiantes_total  estudiantes_varones  estudiantes_mujeres  \
# 0            22156.0              11274.0              10882.0
# 1            28116.0               9760.0              18356.0
# 2            50809.0              18719.0              32090.0
# 3            30984.0               9342.0              21642.0
# 4           111434.0              57606.0              53828.0
#
#    nuevos_inscriptos_total  nuevos_inscriptos_varones  \
# 0                   3697.0                     1793.0
# 1                   6537.0                     2453.0
# 2                  10951.0                     4242.0
# 3                   6682.0                     1995.0
# 4                  22429.0                    11747.0
#
#    nuevos_inscriptos_mujeres  egresados_total  egresados_varones  \
# 0                     1904.0           1304.0              633.0
# 1                     4084.0            810.0              270.0
# 2                     6709.0           3811.0             1174.0
# 3                     4687.0           1740.0              438.0
# 4                    10682.0           8693.0             4439.0
#
#    egresados_mujeres  estudiantes_mujeres_pct  inscripciones_mujeres_pct  \
# 0              671.0                 0.491154                  14.906073
# 1              540.0                 0.652867                  42.558890
# 2             2637.0                 0.631581                  88.484257
# 3             1302.0                 0.698490                  24.346558
# 4             4254.0                 0.483048                 100.115797
#
#    estudiantes_hombres_pct  estudiantes_grupo_pct
# 0                13.355206               0.031802
# 1                36.603461               0.040357
# 2                66.609315               0.072930
# 3                16.267825               0.044474
# 4               151.333689               0.159951

# %%
df_evolucion_universidades.to_csv("data/output/ubicacion_evolucion_genero.csv", encoding = "UTF8", index = False)

# %%
# Evolucion por carrera por universdad
df_evolucion_carrera_universidad = df_alumnos_merged.groupby(["anio","carrera_grupo","Carrera_normalizada","institucion_nombre_new"]).sum()
#df_evolucion_carrera_universidad = df_evolucion_carrera[variables]
df_evolucion_carrera_universidad["estudiantes_mujeres_pct"] = df_evolucion_carrera_universidad.estudiantes_mujeres/df_evolucion_carrera_universidad.estudiantes_total
#incriptas como predictor de composicion e interes.
df_evolucion_carrera_universidad["inscripciones_mujeres_pct"] = df_evolucion_carrera_universidad.nuevos_inscriptos_mujeres/df_evolucion_carrera_universidad.nuevos_inscriptos_total
#agregar ratio de hombres
df_evolucion_carrera_universidad["estudiantes_hombres_pct"] = df_evolucion_carrera_universidad.estudiantes_varones/df_evolucion_carrera_universidad.estudiantes_total
df_evolucion_carrera_universidad = df_evolucion_carrera_universidad.reset_index()

df_evolucion_carrera_universidad.to_csv("data/output/carreras_universidad_evolucion_genero.csv", encoding = "UTF8", index = False)
df_evolucion_carrera_universidad.head(10)
# Out:
#    anio             carrera_grupo Carrera_normalizada  \
# 0  2011  Arquitectura y Urbanismo        Arquitectura
# 1  2011  Arquitectura y Urbanismo        Arquitectura
# 2  2011  Arquitectura y Urbanismo        Arquitectura
# 3  2011  Arquitectura y Urbanismo        Arquitectura
# 4  2011  Arquitectura y Urbanismo        Arquitectura
# 5  2011  Arquitectura y Urbanismo        Arquitectura
# 6  2011  Arquitectura y Urbanismo        Arquitectura
# 7  2011  Arquitectura y Urbanismo        Arquitectura
# 8  2011  Arquitectura y Urbanismo        Arquitectura
# 9  2011  Arquitectura y Urbanismo        Arquitectura
#
#                   institucion_nombre_new  estudiantes_total  \
# 0     Universidad Abierta Interamericana              414.0
# 1  Universidad Argentina John F. Kennedy              305.0
# 2                Universidad Blas Pascal              307.0
# 3        Universidad Catolica de Cordoba              575.0
# 4       Universidad Catolica de La Plata              332.0
# 5          Universidad Catolica de Salta              584.0
# 6       Universidad Catolica de Santa Fe              768.0
# 7        Universidad Nacional de Cordoba             7309.0
# 8       Universidad Nacional de La Plata             7706.0
# 9       Universidad Nacional de La Rioja             1011.0
#
#    estudiantes_varones  estudiantes_mujeres  nuevos_inscriptos_total  \
# 0                250.0                164.0                     96.0
# 1                208.0                 97.0                     35.0
# 2                173.0                134.0                     70.0
# 3                216.0                359.0                    101.0
# 4                172.0                160.0                     69.0
# 5                237.0                347.0                    128.0
# 6                421.0                347.0                    145.0
# 7               3495.0               3814.0                    997.0
# 8               4428.0               3278.0                   1006.0
# 9                607.0                404.0                    126.0
#
#    nuevos_inscriptos_varones  nuevos_inscriptos_mujeres  reinscriptos_total  \
# 0                       58.0                       38.0               318.0
# 1                       23.0                       12.0               270.0
# 2                       41.0                       29.0               237.0
# 3                       32.0                       69.0               474.0
# 4                       34.0                       35.0               263.0
# 5                       45.0                       83.0               456.0
# 6                       72.0                       73.0               623.0
# 7                      464.0                      533.0              6276.0
# 8                      546.0                      460.0              6669.0
# 9                       76.0                       50.0               885.0
#
#    reinscriptos_varones  reinscriptos_mujeres  egresados_total  \
# 0                 192.0                 126.0             18.0
# 1                 185.0                  85.0              7.0
# 2                 132.0                 105.0             33.0
# 3                 184.0                 290.0             90.0
# 4                 138.0                 125.0             27.0
# 5                 192.0                 264.0             32.0
# 6                 349.0                 274.0             43.0
# 7                3018.0                3258.0            486.0
# 8                3876.0                2793.0            297.0
# 9                 531.0                 354.0             30.0
#
#    egresados_varones  egresados_mujeres  estudiantes_mujeres_pct  \
# 0               14.0                4.0                 0.396135
# 1                5.0                2.0                 0.318033
# 2               18.0               15.0                 0.436482
# 3               34.0               56.0                 0.624348
# 4               12.0               15.0                 0.481928
# 5                5.0               27.0                 0.594178
# 6               22.0               21.0                 0.451823
# 7              201.0              285.0                 0.521822
# 8              157.0              140.0                 0.425383
# 9                7.0               23.0                 0.399604
#
#    inscripciones_mujeres_pct  estudiantes_hombres_pct
# 0                   0.395833                 0.603865
# 1                   0.342857                 0.681967
# 2                   0.414286                 0.563518
# 3                   0.683168                 0.375652
# 4                   0.507246                 0.518072
# 5                   0.648438                 0.405822
# 6                   0.503448                 0.548177
# 7                   0.534604                 0.478178
# 8                   0.457256                 0.574617
# 9                   0.396825                 0.600396

# %% [markdown]
# ## ETL Markers de universidades

# %%
def crear_universidad(mapa,latitud, longitud, universidad_nombre, carreras_grupos):
    """ Pone una universidad en el mapa con información en el marker.

    Args:
        latitud (float):
        longitud (float):
        universidad_nombre (str):
        carreras_grupos (list):
    """

# %%
def concatenate_map(grupos_carreras):
    grupos_str = [str(grupo) for grupo in set(grupos_carreras) if pd.notnull(grupo)]
    return ",".join(grupos_str)

# %%
serie_lista_grupos = df_universidades_merged.groupby("institucion_nombre_unidad_academica")["carrera_grupo"].apply(concatenate_map)
serie_lista_carrera = df_universidades_merged.groupby("institucion_nombre_unidad_academica")["carrera_titulo"].apply(concatenate_map)

# %%
df_ubicacion_universidades_grupos = df_universidades.merge(
    serie_lista_grupos, how="left", left_on="institucion_nombre", right_index=True)
df_ubicacion_universidades_grupos = df_ubicacion_universidades_grupos.merge(
    serie_lista_carrera, how="left", left_on="institucion_nombre", right_index=True)

# %%
df_ubicacion_universidades_grupos.to_csv("data/output/universidades_mapa.csv", encoding = "UTF8", index = False)
